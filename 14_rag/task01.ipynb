# %%
# 必要なモジュールをインポート
import os
from dotenv import load_dotenv
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
from llama_index.llms.openai import OpenAI

# 環境変数の取得
load_dotenv("../.env")
os.environ['OPENAI_API_KEY']  = os.environ['API_KEY']

# モデル名
MODEL_NAME = "gpt-4o-mini"

# Indexの構築
documents = SimpleDirectoryReader('./data/text').load_data()
index = VectorStoreIndex.from_documents(documents)

# Chat Engineの作成
llm = OpenAI(model=MODEL_NAME)
chat_engine = index.as_chat_engine(llm=llm)

# チャットの開始
while(True):
    message = input("メッセージを入力:")
    if message.strip()=="":
        break
    display(f"質問:{message}")

    # 質問
    response = chat_engine.chat(message)

    # 回答を表示
    print(f"回答:{response.response}")

print("\n---ご利用ありがとうございました！---")
# Out:
# '質問:こんにちは！'
# 回答:こんにちは！今日はどんなことをお手伝いできますか？
# '質問:退職するときの手続き教えて'
# 回答:退職する際の手続きは以下の通りです。
#
# 1. **退職の申し出と届け出**:
#    - 自己都合退職を希望する場合、退職希望日の1ヶ月前までに直属の上司に申し出る必要があります。
#    - 退職届を提出し、その後、退職日や引き継ぎ内容について上司と人事部と協議します。
#
# 2. **退職までの流れ**:
#    - **引き継ぎ**: 担当業務の進捗や内容、必要な手順を文書にまとめ、後任者へ引き継ぎます。
#    - **社内備品の返却**: 会社の備品（パソコン、スマートフォン、IDカード、制服など）を退職日までに返却します。
#    - **最終面談**: 人事部による退職面談が実施され、退職理由や今後のキャリア計画について意見を伺います。
#
# 3. **退職日の決定**:
#    - 退職日は業務の都合や引き継ぎ内容を考慮し、上司および人事部と話し合いの上で最終決定します。
#
# 他に知りたいことがあれば教えてください！
# '質問:有給休暇以外で取得できる休暇って他になにがあるんだっけ？'
# 回答:有給休暇以外で取得できる休暇には、以下のようなものがあります。
#
# 1. **特別休暇**:
#    - 結婚、出産、家族の不幸などの特別な事情に応じて付与される休暇です。
#
# 2. **リフレッシュ休暇**:
#    - 勤続5年ごとに5日間取得できる休暇で、リフレッシュや自己啓発を目的としています。
#
# 3. **ボランティア休暇**:
#    - 年間2日間の社会貢献活動を支援するための休暇です。
#
# これらの休暇は会社によって異なる場合があるため、具体的な内容は就業規則や人事部に確認することをおすすめします。他に知りたいことがあれば教えてください！
#
# ---ご利用ありがとうございました！---
