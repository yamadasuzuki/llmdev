# %%
name = "Takahashi Yo"
age = 34
nextYearAge = age + 1

print("はじめまして、", name, "と申します。")
print("年齢は", age, "歳です。来年は", nextYearAge, "歳になります。")
print("よろしくお願いします。")
# Out:
# はじめまして、 Takahashi Yo と申します。
# 年齢は 34 歳です。来年は 35 歳になります。
# よろしくお願いします。
